# %%
import pandas as pd

# %%
df=pd.read_csv("./data.csv")

# %%
def greetings(name):
    print("Good Day " + name)

# %%
greetings("james")
# Out:
# Good Day james

# %%
df.columns
# Out:
# Index(['age', 'gender', 'review', 'education', 'purchased'], dtype='object')

# %%
df['gender']=df['gender'].str.replace("Female","Lady")

# %%
def change(x):
    x.pandas.Series.str.replace("No","Better luck")

# %%
df['purchased']=df['purchased'].apply(change)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [65], line 1
# ----> 1 df['purchased']=df['purchased'].apply(change)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\apply.py:1088, in SeriesApply.apply(self)
#    1084 if isinstance(self.f, str):
#    1085     # if we are a string, try to dispatch
#    1086     return self.apply_str()
# ...

# %%
df
# Out:
#     age gender   review education purchased
# 0    30   None  Average    School        No
# 1    68   None     Poor        UG        No
# 2    70   None     Good        PG        No
# 3    72   None     Good        PG        No
# 4    16   None  Average        UG        No
# 5    31   None  Average    School       Yes
# 6    18   None     Good    School        No
# 7    60   None     Poor    School       Yes
# 8    65   None  Average        UG        No
# 9    74   None     Good        UG       Yes
# 10   98   None     Good        UG       Yes
# 11   74   None     Good        UG       Yes
# 12   51   None     Poor    School        No
# 13   57   None  Average    School        No
# 14   15   None     Poor        PG       Yes
# 15   75   None     Poor        UG        No
# 16   59   None     Poor        UG       Yes
# 17   22   None     Poor        UG       Yes
# 18   19   None     Good    School        No
# 19   97   None     Poor        PG       Yes
# ...
