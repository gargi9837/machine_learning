# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data=pd.read_csv('./Data Visualization Assignmnet.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113 entries, 0 to 112
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DATE         111 non-null    object
#  1   DESCRIPTION  111 non-null    object
#  2   UNIT         111 non-null    float64
#  3   PLACE        103 non-null    object
# dtypes: float64(1), object(3)
# memory usage: 3.7+ KB

# %%
data1.describe()
# Out:
#              UNIT
# count  103.000000
# mean     1.718447
# std      1.097390
# min      1.000000
# 25%      1.000000
# 50%      1.000000
# 75%      2.000000
# max      6.000000

# %%
data.isnull().sum()
# Out:
# DATE            2
# DESCRIPTION     2
# UNIT            2
# PLACE          10
# dtype: int64

# %%
data1=data.dropna()
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103 entries, 0 to 102
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DATE         103 non-null    object
#  1   DESCRIPTION  103 non-null    object
#  2   UNIT         103 non-null    float64
#  3   PLACE        103 non-null    object
# dtypes: float64(1), object(3)
# memory usage: 4.0+ KB

# %%
data1['UNIT']=data1['UNIT'].astype(int)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7948\674583824.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['UNIT']=data1['UNIT'].astype(int)

# %%
data1['UNIT'].unique()
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
data1
# Out:
#               DATE DESCRIPTION  UNIT          PLACE
# 0    01 April 2022        Beef     1    Kolenchery
# 1    01 April 2022        Fish     1    Kolenchery
# 2    03 April 2022        Beef     2  Tripunithura
# 3    05 April 2022      Prawns     1     Bangalore
# 4    06 April 2022       Dates     1      Mangalore
# ..             ...         ...   ...            ...
# 98    26 June 2022      Prawns     1          Kochi
# 99    28 June 2022      Prawns     4       Kottayam
# 100   28 June 2022        Fish     3       Kottayam
# 101   28 June 2022   King Fish     1       Kottayam
# 102   28 June 2022        Beef     4       Kottayam
#
# [103 rows x 4 columns]

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103 entries, 0 to 102
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DATE         103 non-null    datetime64[ns]
#  1   DESCRIPTION  103 non-null    object
#  2   UNIT         103 non-null    int32
#  3   PLACE        103 non-null    object
#  4   MONTH        103 non-null    object
# dtypes: datetime64[ns](1), int32(1), object(3)
# memory usage: 4.4+ KB

# %%
data1['DESCRIPTION'].value_counts()
# Out:
# Beef         30
# Prawns       28
# Fish         12
# Mango        10
# Lemon         7
# KingFish      7
# Dryfruits     5
# Dates         3
# Kadumanga     1
# Name: DESCRIPTION, dtype: int64

# %%
data1['DESCRIPTION']=data1['DESCRIPTION'].str.replace(' ','')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7948\2724662063.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['DESCRIPTION']=data1['DESCRIPTION'].str.replace(' ','')

# %%
data1['DESCRIPTION'].unique()
# Out:
# array(['Beef', 'Fish', 'Prawns', 'Dates', 'Mango', 'Lemon', 'Dryfruits',
#        'KingFish', 'Kadumanga'], dtype=object)

# %%
data1.reset_index(drop=True)
# Out:
#               DATE DESCRIPTION  UNIT          PLACE
# 0    01 April 2022        Beef     1    Kolenchery
# 1    01 April 2022        Fish     1    Kolenchery
# 2    03 April 2022        Beef     2  Tripunithura
# 3    05 April 2022      Prawns     1     Bangalore
# 4    06 April 2022       Dates     1      Mangalore
# ..             ...         ...   ...            ...
# 98    26 June 2022      Prawns     1          Kochi
# 99    28 June 2022      Prawns     4       Kottayam
# 100   28 June 2022        Fish     3       Kottayam
# 101   28 June 2022    KingFish     1       Kottayam
# 102   28 June 2022        Beef     4       Kottayam
#
# [103 rows x 4 columns]

# %%
data1['PLACE']=data1['PLACE'].str.replace(' ','')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7948\3361138273.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['PLACE']=data1['PLACE'].str.replace(' ','')

# %%
data1['PLACE'].unique()
# Out:
# array(['Kolenchery', 'Tripunithura', 'Bangalore', 'Mangalore',
#        'Pathanamthitta', 'Pune', 'Malappuram', 'Padappai-Tamilnadu',
#        'Nettoor', 'Kottayam', 'Jabalpur-Madhyapradesh', 'Eroor-Vytila',
#        'Kanjiramttom', 'Vazhakala', 'Noida-UP', 'Mumbai', 'UnitedStates',
#        'BangaloretoUS', 'ToKottayam', 'Chennai', 'Kumily',
#        'Mangalore-Ullal', 'Kochi', 'Eloor', 'Tripunithurra', 'Aroor',
#        'Thrissur/Guruvayoor', 'Kakkanad', 'malappuram', 'Kadavanthra',
#        'kadavanthra'], dtype=object)

# %%
date=data1['DATE']
unit=data1['UNIT']

# %%
data1['DATE']=pd.to_datetime(data1['DATE'])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7948\2786701020.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['DATE']=pd.to_datetime(data1['DATE'])

# %%
data1['MONTH']=data1['DATE'].dt.month_name()
data1
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7948\1253228083.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['MONTH']=data1['DATE'].dt.month_name()
#           DATE DESCRIPTION  UNIT         PLACE  MONTH
# 0   2022-04-01        Beef     1    Kolenchery  April
# 1   2022-04-01        Fish     1    Kolenchery  April
# 2   2022-04-03        Beef     2  Tripunithura  April
# 3   2022-04-05      Prawns     1     Bangalore  April
# 4   2022-04-06       Dates     1     Mangalore  April
# ..         ...         ...   ...           ...    ...
# 98  2022-06-26      Prawns     1         Kochi   June
# 99  2022-06-28      Prawns     4      Kottayam   June
# 100 2022-06-28        Fish     3      Kottayam   June
# ...

# %%
data1['MONTH'].unique()
# Out:
# array(['April', 'May', 'June'], dtype=object)

# %%
sns.lineplot(x='MONTH',y='DESCRIPTION',data=data1)
# Out:
# <AxesSubplot:xlabel='MONTH', ylabel='DESCRIPTION'>

# %%
data1['DESCRIPTION'].value_counts().plot(kind='pie',autopct='%1.0f%%')
# Out:
# <AxesSubplot:ylabel='DESCRIPTION'>

# %%
data1['MONTH'].value_counts().plot(kind='pie',autopct='%1.0f%%')
# Out:
# <AxesSubplot:ylabel='MONTH'>

# %%
data1['PLACE'].value_counts().plot(kind='pie',autopct='%1.0f%%')
# Out:
# <AxesSubplot:ylabel='PLACE'>

# %%
data1['DESCRIPTION'].value_counts()
# Out:
# Beef         30
# Prawns       28
# Fish         12
# Mango        10
# Lemon         7
# KingFish      7
# Dryfruits     5
# Dates         3
# Kadumanga     1
# Name: DESCRIPTION, dtype: int64

# %%
plt.figure(figsize=(20,10))
plt.xticks(rotation=90)
sns.barplot(x='PLACE',y='UNIT',data=data1)
# Out:
# <AxesSubplot:xlabel='PLACE', ylabel='UNIT'>

# %%
data1['PLACE'].value_counts()
# Out:
# Malappuram                10
# Mumbai                     6
# Noida-UP                   6
# Eloor                      6
# Kottayam                   6
# Kochi                      5
# ToKottayam                 5
# Eroor-Vytila               5
# UnitedStates               5
# Pathanamthitta             4
# Nettoor                    4
# BangaloretoUS              4
# Tripunithura               4
# Kadavanthra                3
# Kolenchery                 3
# Vazhakala                  3
# Pune                       3
# Kanjiramttom               2
# Jabalpur-Madhyapradesh     2
# Chennai                    2
# Kumily                     2
# Mangalore-Ullal            2
# Kakkanad                   2
# Bangalore                  2
# Padappai-Tamilnadu         1
# Mangalore                  1
# Tripunithurra              1
# Aroor                      1
# Thrissur/Guruvayoor        1
# malappuram                 1
# kadavanthra                1
# Name: PLACE, dtype: int64
