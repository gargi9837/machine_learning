# %%
import pandas as pd

# %%
df=pd.read_csv("./Fish.csv")
df.head()
df.mean()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11456\2694819234.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# Weight     398.326415
# Length1     26.247170
# Length2     28.415723
# Length3     31.227044
# Height       8.970994
# Width        4.417486
# dtype: float64

# %%
species=df['Species'].value_counts().plot(kind="pie",autopct='%1.0f%%')

# %%
#weight.mean()
weight_pike1=df['Species']

# %%
p=df.loc[df.Species=='Perch','Species']
c=p.value_counts()
c
i=df['Species'].value_counts()
a=c/i
a
# Out:
# Bream        NaN
# Parkki       NaN
# Perch        1.0
# Pike         NaN
# Roach        NaN
# Smelt        NaN
# Whitefish    NaN
# Name: Species, dtype: float64

# %%
perch=df.loc[df.Species=='Perch','Species']
perch_count=perch.value_counts()
perch_count
# Out:
# Perch    56
# Name: Species, dtype: int64

# %%
perch1=df.loc[:,'Species']
perch1
# Out:
# 0      Bream
# 1      Bream
# 2      Bream
# 3      Bream
# 4      Bream
#        ...
# 154    Smelt
# 155    Smelt
# 156    Smelt
# 157    Smelt
# 158    Smelt
# Name: Species, Length: 159, dtype: object

# %%
species1=df['Species']
all=species1.shape[0]
all
# Out:
# 159

# %% [markdown]
# perch_avg=perch_count/all*100
# perch_avg.plot(kind='pie')
