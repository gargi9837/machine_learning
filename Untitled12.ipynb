# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df=pd.read_csv('./Data Visualization Assignmnet.csv')

# %%
df['PLACE']=df['PLACE'].str.replace("malappuram","Malappuram")
df['PLACE']=df['PLACE'].str.replace("kadavanthra","Kadavanthra")
df['PLACE']=df['PLACE'].str.replace('Tripunithura ',"Tripunithura")
df['PLACE']=df['PLACE'].str.replace('Tripunithurra',"Tripunithura")

# %%
df['PLACE'].value_counts()
# Out:
# Malappuram                  11
# Noida - UP                   6
# Eloor                        6
# Mumbai                       6
# Kottayam                     6
# Eroor - Vytila               5
# Kochi                        5
# To Kottayam                  5
# United States                5
# Tripunithura                 5
# Bangalore to US              4
# Kadavanthra                  4
# Nettoor                      4
# Pathanamthitta               4
# Kolenchery                   3
# Vazhakala                    3
# Pune                         3
# Kakkanad                     2
# Mangalore - Ullal            2
# Kanjiramttom                 2
# Chennai                      2
# Jabalpur - Madhyapradesh     2
# Kumily                       2
# Padappai- Tamilnadu          1
# Mangalore                    1
# Bangalore                    1
# Aroor                        1
# Thrissur/ Guruvayoor         1
# Bangalore                    1
# Name: PLACE, dtype: int64

# %%
df=df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103 entries, 0 to 102
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DATE         103 non-null    object
#  1   DESCRIPTION  103 non-null    object
#  2   UNIT         103 non-null    float64
#  3   PLACE        103 non-null    object
# dtypes: float64(1), object(3)
# memory usage: 4.0+ KB

# %%
df['UNIT']=df['UNIT'].astype(int)

# %%
df.reset_index(drop=True)
# Out:
#               DATE DESCRIPTION  UNIT         PLACE
# 0    01 April 2022        Beef     1   Kolenchery
# 1    01 April 2022        Fish     1   Kolenchery
# 2    03 April 2022        Beef     2  Tripunithura
# 3    05 April 2022      Prawns     1    Bangalore
# 4    06 April 2022       Dates     1     Mangalore
# ..             ...         ...   ...           ...
# 98    26 June 2022      Prawns     1         Kochi
# 99    28 June 2022      Prawns     4      Kottayam
# 100   28 June 2022        Fish     3      Kottayam
# 101   28 June 2022   King Fish     1      Kottayam
# 102   28 June 2022        Beef     4      Kottayam
#
# [103 rows x 4 columns]

# %%
df['DATE']=pd.to_datetime(df['DATE'])

# %%
df['MONTH']=df['DATE'].dt.month_name()

# %%
df['DESCRIPTION'].value_counts().plot(kind='pie',autopct='%1.0f%%')
# Out:
# <AxesSubplot:ylabel='DESCRIPTION'>

# %%
df['PLACE'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['MONTH'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['DESCRIPTION']=df['DESCRIPTION'].str.replace('Dry Fruits','Dry fruits')

# %%
df['DESCRIPTION'].unique()
# Out:
# array(['Beef', 'Fish', 'Prawns', 'Dates', 'Mango', 'Lemon', 'Dry fruits',
#        'King Fish', 'Kadumanga'], dtype=object)

# %%
place=df['PLACE']
dishes=df['DESCRIPTION']

# %%
plt.plot(dishes,place)
