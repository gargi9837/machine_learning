# %%
import pandas as pd

# %%
fdata=pd.read_csv('children_stats_only (2) (1).csv')

# %%
fdata['Age ']
# Out:
# 0      7
# 1      7
# 2      5
# 3     10
# 4     10
# 5      6
# 6      8
# 7     11
# 8      7
# 9     11
# 10     8
# 11     8
# 12     5
# 13    10
# 14    10
# 15     5
# 16     9
# 17     6
# 18     7
# 19    11
# 20     8
# 21     8
# 22    10
# Name: Age , dtype: int64

# %%
fdata['1.On a scale of 1-5, how much do you feel irritable if there is a delay in food or if a meal is missed?'].plot(kind='bar')
# Out:
# <AxesSubplot:>
